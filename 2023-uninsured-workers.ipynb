# %%
import pandas as pd

# %%
df_w = pd.read_excel("data/FOIA request cleaned up.xlsx")
df_w
# Out:
#    Reference Number Created Date      Created By  Load Date  Updated By  \
# 0              b(6)   2018-10-08  FTCCIS-FTCUSER 2018-10-08         NaN
# 1              b(6)   2018-10-09  FTCCIS-FTCUSER 2018-10-09  CRSS\apugh
# 2              b(6)   2018-10-10           BROSS 2018-10-10         NaN
# 3              b(6)   2019-03-13  FTCCIS-FTCUSER 2019-03-13         NaN
# 4              b(6)   2019-09-08  FTCCIS-FTCUSER 2019-09-08         NaN
# ..              ...          ...             ...        ...         ...
# 79             b(6)   2021-12-09  FTCCIS-FTCUSER 2021-12-09         NaN
# 80             b(6)   2021-12-13  FTCCIS-FTCUSER 2021-12-13  mronquillo
# 81             b(6)   2022-01-17  FTCCIS-FTCUSER 2022-01-17         NaN
# 82             b(6)   2022-01-18  FTCCIS-FTCUSER 2022-01-18         NaN
# 83             b(6)   2022-02-27  FTCCIS-FTCUSER 2022-02-27         NaN
#
#    Updated Date       Complaint Source Originator Reference Number Language  \
# ...
